# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd
plt.style.use('science')

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#     V_BB    V_BE  I_b (micro)  I_c( mA)  V_CC  V_CE
# 0    0.0  0.0000            0     0.000     2     2
# 1    0.1  0.1232            0     0.000     2     2
# 2    0.2  0.2340            0     0.000     2     2
# 3    0.4  0.4580            0     0.007     2     2
# 4    0.5  0.5640            4     0.400     2     2
# 5    0.6  0.6390           50     6.620     2     2
# 6    0.7  0.6740          139    18.230     2     2
# 7    0.8  0.6960          244    32.300     2     2
# 8    0.9  0.7210          357    47.400     2     2
# 9    1.0  0.7450          480    63.400     2     2
# 10   1.1  0.7690          605    79.600     2     2
# 11   1.2  0.7810          745    97.300     2     2
# 12   0.0  0.0000            0     0.000     3     3
# 13   0.1  0.1156            0     0.000     3     3
# 14   0.2  0.2360            0     0.000     3     3
# 15   0.3  0.3430            0     0.000     3     3
# 16   0.4  0.4620            0     0.006     3     3
# 17   0.5  0.5690            3     0.488     3     3
# 18   0.6  0.6390           41     6.950     3     3
# 19   0.7  0.6690          115    19.860     3     3
# 20   0.8  0.6830          210    38.100     3     3
# 21   0.9  0.6890          305    57.100     3     3
# 22   1.0  0.6960          395    76.300     3     3
# 23   1.1  0.7090          490    98.100     3     3
# 24   1.2  0.7870          530   111.200     3     3
# 25   0.0  0.0000            0     0.000     4     4
# 26   0.1  0.1150            0     0.000     4     4
# 27   0.2  0.2400            0     0.000     4     4
# 28   0.3  0.3450            0     0.000     4     4
# 29   0.4  0.4600            0     0.010     4     4
# 30   0.5  0.5670            4     0.556     4     4
# 31   0.6  0.6420           46     8.030     4     4
# 32   0.7  0.6670          124    22.600     4     4
# 33   0.8  0.6820          216    40.000     4     4
# 34   0.9  0.6970          305    58.800     4     4
# 35   1.0  0.7030          400    81.400     4     4
# 36   1.1  0.7240          475   100.600     4     4

# %%
VB2V = np.asarray(df['V_BE'][:12], dtype='float64')
IB2V = np.asarray(df['I_b (micro)'][:12], dtype='float64')

VB3V = np.asarray(df['V_BE'][12:25], dtype='float64')
IB3V = np.asarray(df['I_b (micro)'][12:25], dtype='float64')

VB4V = np.asarray(df['V_BE'][25:], dtype='float64')
IB4V = np.asarray(df['I_b (micro)'][25:], dtype='float64')

# %%
fig,axes = plt.subplots(1,1,figsize=(16,9), dpi = 300)
axes.plot(VB2V, IB2V, 'o-', label='V_B = 2V')
axes.plot(VB3V, IB3V, 'o-', label='V_B = 3V')
axes.plot(VB4V, IB4V, 'o-', label='V_B = 4V')
axes.legend()
